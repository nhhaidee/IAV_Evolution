# %%
from shap_rscu import load_and_preprocess_data, analyze_codon_shap_trends, codon_trajectory_plot_grid, \
compute_rscu_shap_correlations, get_codon_type, volcano_plot_grid, codon_category_map
import pandas as pd
import numpy as np

# %%
segments=["01_PB2", "02_PB1", "03_PA", "04_HA", "05_NP", "06_NA", "07_MP", "08_NS"]

# %%
corr_dfs = {}
trend_dfs = {}
for seg in segments:
    print("="*50)
    print(f"Processing segment {seg}")
    print("="*50)

    shap_df_post2020, rscu_df_post2020, codon_cols  = load_and_preprocess_data(seg, data_path='/home/hnguyen/Documents/PhD/Part2/Paper_02_Preparation/data/section3_4_5', file_pattern_shap ='All_True_Label_Post2020_', file_pattern_rscu ='All_True_Label_Post2020_', datatype= 'post2020', verbose=True)
    np.testing.assert_array_equal(shap_df_post2020['seq_ID'].to_numpy(), rscu_df_post2020['seq_ID'].to_numpy())
    shap_df_pre2020,  rscu_df_pre2020, _            = load_and_preprocess_data(seg, data_path='/home/hnguyen/Documents/PhD/Part2/Paper_02_Preparation/data/section3_4_5', file_pattern_shap ='All_True_Label_Training_', file_pattern_rscu ='All_True_Label_Training_', datatype= 'pre2020', verbose=True)
    np.testing.assert_array_equal(shap_df_pre2020['seq_ID'].to_numpy(), rscu_df_pre2020['seq_ID'].to_numpy())
    shap_df_H5Nx, rscu_df_H5Nx, _                   = load_and_preprocess_data(seg, data_path='/home/hnguyen/Documents/PhD/Part2/Paper_02_Preparation/data/section3_4_5/H5Nx_Codon_Shap', file_pattern_shap ='H5Nx_', file_pattern_rscu ='H5Nx_', datatype= 'post2020', verbose=True)
    np.testing.assert_array_equal(shap_df_H5Nx.columns.to_numpy(), shap_df_post2020.columns.to_numpy())
    codon_categories = codon_category_map(codon_cols)
    
    shap_df = pd.concat([shap_df_pre2020, shap_df_post2020, shap_df_H5Nx], ignore_index=True)
    rscu_df = pd.concat([rscu_df_pre2020, rscu_df_post2020, rscu_df_H5Nx], ignore_index=True)

    #shap_df = shap_df[~shap_df['subtype'].isin(['H1N1', 'H3N2'])]
    #rscu_df = rscu_df[~rscu_df['subtype'].isin(['H1N1', 'H3N2'])]
    print (shap_df.shape, rscu_df.shape)
    
    corr_df = compute_rscu_shap_correlations(shap_df, rscu_df, codon_cols, codon_categories, method='spearman')
    corr_df.to_csv(f'../../results/Spearman/{seg}_corr_df_spearman.csv')
    corr_dfs[seg]= corr_df

    trend_df = analyze_codon_shap_trends(shap_df, codon_cols, codon_categories)
    trend_df.to_csv(f'../../results/Spearman/{seg}_trend_df.csv')
    trend_dfs[seg] = trend_df
    #skewness_analysis(shap_df, codon_cols)
# Out:
# ==================================================
# Processing segment 01_PB2
# ==================================================
# Combined SHAP shape: (833250, 66)
# Combined RSCU shape: (833250, 66)
# Cleaned SHAP shape: (83325, 65)
# Cleaned RSCU shape: (83325, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2           33  38365               633  39031
# H1N1           58  35179               679  35916
# H5N1         4350     27                86   4463
# H5N8         1109      0                 1   1110
# H1N2           13     20               605    638
# H9N2          463     23                 0    486
# H3N8          269      8                18    295
# H5N6          121     13                 1    135
# H5N5          119      0                 7    126
# H4N6          115      0                 0    115
# H7N3           82      0                 0     82
# H3              2     63                 0     65
# H6N6           55      0                 0     55
# H6N2           51      0                 1     52
# H5N3           51      0                 0     51
# H11N9          44      0                 0     44
# H6N1           43      0                 0     43
# Unknown         4      5                30     39
# H10N3          35      4                 0     39
# H5N2           38      0                 0     38
# ----------------------------------------
# Combined SHAP shape: (78732, 65)
# Combined RSCU shape: (78732, 65)
# Cleaned SHAP shape: (78732, 65)
# Cleaned RSCU shape: (78732, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2          307  25239              2193  27739
# H1N1          557  20211              3345  24113
# H9N2         3617     46                47   3710
# H5N1         2889    373                44   3306
# H1N2           57     56              2386   2499
# H7N9          696    894                 3   1593
# H3N8         1224      0               217   1441
# H5N6         1217     29                20   1266
# H4N6         1245      0                 2   1247
# H5N2         1235      0                 5   1240
# H5N8         1143      0                 0   1143
# Unknown       950     67               105   1122
# H6N2          594      0                 0    594
# H7N3          580      2                 0    582
# H10N7         475      0                 0    475
# H7N7          414     32                11    457
# H6N6          436      0                 2    438
# H6N1          391      1                 0    392
# H11N9         375      0                 0    375
# H7N2          288      2                 4    294
# ----------------------------------------
# Combined SHAP shape: (103820, 66)
# Combined RSCU shape: (103820, 66)
# Cleaned SHAP shape: (10382, 65)
# Cleaned RSCU shape: (10382, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H5N1         8222     28              1883  10133
# H5N5          111      0                20    131
# H5N2           92      0                 0     92
# H5N9           10      0                 0     10
# H5N3            7      0                 0      7
# H5N7            4      0                 0      4
# H5N4            3      0                 0      3
# H5N6            2      0                 0      2
# ----------------------------------------
# (172439, 65) (172439, 65)
# ==================================================
# Processing segment 02_PB1
# ==================================================
# Combined SHAP shape: (770410, 66)
# Combined RSCU shape: (770410, 66)
# Cleaned SHAP shape: (77041, 65)
# Cleaned RSCU shape: (77041, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2           34  36666               606  37306
# H1N1           44  30829               659  31532
# H5N1         4353     28                75   4456
# H5N8         1112      0                 1   1113
# H1N2           15     23               604    642
# H9N2          369     21                 1    391
# H3N8          269      7                20    296
# H5N6          117     16                 1    134
# H5N5          125      0                 9    134
# H4N6          104      0                 0    104
# H7N3           87      0                 0     87
# H3              1     57                 0     58
# H6N6           54      0                 0     54
# H6N2           51      0                 1     52
# H5N3           45      0                 0     45
# H6N1           41      0                 0     41
# H11N9          39      0                 0     39
# H10N3          34      4                 0     38
# H5N2           38      0                 0     38
# Unknown         4      2                28     34
# ----------------------------------------
# Combined SHAP shape: (77369, 65)
# Combined RSCU shape: (77369, 65)
# Cleaned SHAP shape: (77369, 65)
# Cleaned RSCU shape: (77369, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2          307  25430              2211  27948
# H1N1          551  18732              3309  22592
# H9N2         3593     47                48   3688
# H5N1         2959    371                45   3375
# H1N2           54     53              2355   2462
# H7N9          711    890                 2   1603
# H3N8         1248      0               211   1459
# H5N6         1248     27                19   1294
# H4N6         1287      0                 2   1289
# H5N2         1222      0                 3   1225
# H5N8         1108      0                 0   1108
# Unknown       925     57                97   1079
# H6N2          629      0                 0    629
# H7N3          574      2                 0    576
# H10N7         489      0                 0    489
# H6N6          457      0                 2    459
# H6N1          374      1                 0    375
# H11N9         369      0                 0    369
# H7N7          330      3                11    344
# H7N2          295      2                 3    300
# ----------------------------------------
# Combined SHAP shape: (98970, 66)
# Combined RSCU shape: (98970, 66)
# Cleaned SHAP shape: (9897, 65)
# Cleaned RSCU shape: (9897, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H5N1         7917     24              1729   9670
# H5N5          103      0                13    116
# H5N2           85      0                 0     85
# H5N9           10      0                 0     10
# H5N3            8      0                 0      8
# H5N7            4      0                 0      4
# H5N4            2      0                 0      2
# H5N6            2      0                 0      2
# ----------------------------------------
# (164307, 65) (164307, 65)
# ==================================================
# Processing segment 03_PA
# ==================================================
# Combined SHAP shape: (857720, 66)
# Combined RSCU shape: (857720, 66)
# Cleaned SHAP shape: (85772, 65)
# Cleaned RSCU shape: (85772, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2           34  40732               617  41383
# H1N1           50  35199               658  35907
# H5N1         4562     29                79   4670
# H5N8         1070      1                 1   1072
# H1N2           17     23               610    650
# H9N2          425     20                 1    446
# H3N8          242      6                17    265
# H5N6          119     16                 1    136
# H5N5          121      0                 8    129
# H4N6          107      0                 0    107
# H7N3           78      0                 0     78
# H3              2     73                 0     75
# H6N2           54      0                 1     55
# H6N6           51      0                 0     51
# H5N3           48      0                 0     48
# H10N3          40      5                 0     45
# H6N1           44      0                 0     44
# H11N9          44      0                 0     44
# H5N2           41      0                 0     41
# Unknown         2      1                31     34
# ----------------------------------------
# Combined SHAP shape: (77642, 65)
# Combined RSCU shape: (77642, 65)
# Cleaned SHAP shape: (77642, 65)
# Cleaned RSCU shape: (77642, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2          311  24635              2204  27150
# H1N1          549  19853              3382  23784
# H9N2         3506     47                41   3594
# H5N1         2888    381                43   3312
# H1N2           57     54              2440   2551
# H7N9          637    909                 3   1549
# H3N8         1235      0               214   1449
# H4N6         1262      0                 2   1264
# H5N2         1221      0                 4   1225
# H5N6         1169     30                20   1219
# H5N8         1136      0                 0   1136
# Unknown       896     74               115   1085
# H6N2          612      0                 0    612
# H7N3          579      1                 0    580
# H10N7         477      0                 0    477
# H6N6          412      0                 2    414
# H6N1          390      1                 0    391
# H11N9         382      0                 0    382
# H7N7          331      4                11    346
# H7N2          296      2                 7    305
# ----------------------------------------
# Combined SHAP shape: (103680, 66)
# Combined RSCU shape: (103680, 66)
# Cleaned SHAP shape: (10368, 65)
# Cleaned RSCU shape: (10368, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H5N1         8198     30              1912  10140
# H5N5          103      0                14    117
# H5N2           82      0                 0     82
# H5N9           12      0                 0     12
# H5N3            8      0                 0      8
# H5N7            4      0                 0      4
# H5N4            2      0                 0      2
# H5N6            2      0                 0      2
# H5              1      0                 0      1
# ----------------------------------------
# (173782, 65) (173782, 65)
# ==================================================
# Processing segment 04_HA
# ==================================================
# Combined SHAP shape: (1058040, 66)
# Combined RSCU shape: (1058040, 66)
# Cleaned SHAP shape: (105804, 65)
# Cleaned RSCU shape: (105804, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2           32  46432              1519  47983
# H1N1           50  45286              1859  47195
# H5N1         4406     44                87   4537
# H1N2           17     22              1587   1626
# H5N8         1140      0                 1   1141
# H9N2          662     29                 1    692
# H3              2    618                 5    625
# H3N8          240      5                81    326
# H1              0    203                78    281
# H5N6          133     22                 1    156
# H5N5          130      0                 9    139
# H4N6          107      0                 0    107
# H7N3           82      0                 0     82
# H6N2           68      0                 1     69
# H6N6           54      0                 0     54
# H6N1           53      0                 0     53
# H5N3           51      0                 0     51
# H11N9          50      0                 0     50
# H10N3          42      4                 0     46
# H5N2           45      0                 0     45
# ----------------------------------------
# Combined SHAP shape: (148068, 65)
# Combined RSCU shape: (148068, 65)
# Cleaned SHAP shape: (148068, 65)
# Cleaned RSCU shape: (148068, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2          400  52167              3555  56122
# H1N1          623  44417              6056  51096
# H9N2         8406     54                60   8520
# H5N1         5229    520                65   5814
# H1N2           63     58              4592   4713
# H9           1893      0                 0   1893
# H3N8         1355      0               518   1873
# H7N9          735    911                 3   1649
# H5N8         1508      0                 0   1508
# H5N2         1468      0                 2   1470
# H5N6         1293     30                19   1342
# H4N6         1290      0                 3   1293
# H6N2          789      0                 0    789
# H3             80    573                10    663
# H7N3          648      2                 0    650
# H7N7          514     41                12    567
# H6N6          515      0                 1    516
# H6N1          511      1                 0    512
# H10N7         485      0                 0    485
# H11N9         420      0                 0    420
# ----------------------------------------
# Combined SHAP shape: (95930, 66)
# Combined RSCU shape: (95930, 66)
# Cleaned SHAP shape: (9593, 65)
# Cleaned RSCU shape: (9593, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H5N1         7520     47              1770   9337
# H5N5          104      0                13    117
# H5N2          104      1                 0    105
# H5N9            9      0                 0      9
# H5N3            8      0                 0      8
# H5N8            7      0                 0      7
# H5N7            4      0                 0      4
# H5              1      1                 0      2
# H5N4            2      0                 0      2
# H5N6            2      0                 0      2
# ----------------------------------------
# (263465, 65) (263465, 65)
# ==================================================
# Processing segment 05_NP
# ==================================================
# Combined SHAP shape: (647680, 66)
# Combined RSCU shape: (647680, 66)
# Cleaned SHAP shape: (64768, 65)
# Cleaned RSCU shape: (64768, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2           34  29702               542  30278
# H1N1           55  26417               634  27106
# H5N1         3748     39                64   3851
# H5N8          881      1                 0    882
# H1N2           14     18               570    602
# H9N2          448     21                 1    470
# H3N8          237      5                19    261
# H5N5          116      0                 5    121
# H5N6           88     16                 1    105
# H4N6           94      0                 0     94
# H3              1     74                 1     76
# H7N3           69      0                 0     69
# H6N2           51      0                 1     52
# H6N6           50      0                 0     50
# H6N1           47      0                 0     47
# H11N9          45      0                 0     45
# H5N3           45      0                 0     45
# H1              0     40                 2     42
# H5N2           40      0                 0     40
# H10N3          35      4                 0     39
# ----------------------------------------
# Combined SHAP shape: (67847, 65)
# Combined RSCU shape: (67847, 65)
# Cleaned SHAP shape: (67847, 65)
# Cleaned RSCU shape: (67847, 65)
#
# Sequence Count by Subtype & Host Group:
# host_group  Avian  Human  Non-human Mammal  Total
# subtype
# H3N2          316  20950              2152  23418
# H1N1          539  15850              3304  19693
# H9N2         3368     47                43   3458
# H5N1         2830    377                43   3250
# H1N2           61     54              2346   2461
# H7N9          592    783                 2   1377
# H3N8         1124      0               236   1360
# H4N6         1113      0                 2   1115
# H5N2         1085      0                 5   1090
# H5N6         1028     25                19   1072
# Unknown       874     79               114   1067
# H5N8          935      0                 0    935
# H6N2          580      0                 0    580
# H7N3          531      1                 0    532
# H10N7         414      0                 0    414
# H6N6          400      0                 1    401
# H6N1          379      1                 0    380
# H11N9         352      0                 0    352
# H7N7          318      3                14    335
# H3N6          229      0                 5    234
# ----------------------------------------

# %%
# codon_categories = codon_category_map(codon_cols)

# %%
volcano_plot_grid(corr_dfs, codon_categories, save_path="../../results/Figure_5_RSCU_SHAP_Spearman_All_Subtype.png", segments=["01_PB2", "04_HA"], grid_shape=(2, 3), count_significant_only=True)

# %%
volcano_plot_grid(corr_dfs, codon_categories, save_path="../../results/Supplementary_Figure_S8_RSCU_SHAP_Spearman_All_Subtype.png", segments=["02_PB1", "03_PA", "05_NP", "06_NA", "07_MP", "08_NS"], grid_shape=(6, 3), count_significant_only=True)

# %%
codon_trajectory_plot_grid(trend_dfs, codon_categories, save_path="../../results/Figure_6_Trajectories_All_Subtype.png")
